# %%
 # =============================================================================
#
# Analisis básico
#
# =============================================================================

#
# Carga de datos
#
import functions  #  type: ignore


df_orig = functions.load_data()
display(df_orig.head())
display(df_orig.shape)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[5], line 13
#       1  # =============================================================================
#       2 #
#       3 # Analisis básico
#    (...)      8 # Carga de datos
#       9 #
#      10 import functions  #  type: ignore
# ---> 13 df_orig = functions.load_data()
#      14 display(df_orig.head())
#      15 display(df_orig.shape)
#
# AttributeError: module 'functions' has no attribute 'load_data'
